# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(150, 10, 300)
plt.hist(x)
plt.show()

# %%
x
# Out:
# array([124.40890426, 143.27654525, 157.78497305, 145.63952893,
#        144.49251723, 150.53623296, 138.80403021, 150.45531438,
#        139.37268593, 151.36166938, 148.97979615, 144.74579214,
#        134.43424999, 156.04384871, 154.40623592, 139.58815775,
#        155.30135825, 150.64242119, 148.12667364, 154.38253429,
#        155.43776153, 144.47418459, 150.04206905, 144.25994703,
#        146.21693723, 143.6570772 , 167.70496583, 149.97610345,
#        149.78610573, 158.38652924, 153.70897803, 143.58825507,
#        138.8969529 , 151.67386699, 150.03290645, 157.86277632,
#        132.27764943, 156.87355532, 155.00821814, 148.34729227,
#        141.32567952, 154.5566949 , 156.87610617, 152.09837797,
#        162.20771714, 142.11318152, 157.40721981, 135.60567167,
#        157.21425471, 118.32566053, 141.1487359 , 136.62688423,
#        125.40340928, 155.72772815, 145.84831769, 148.69549464,
#        159.28876378, 141.17428504, 156.32670241, 144.63605973,
# ...

# %%
x = [0.2,3.7,1.2,13.7,1.5,0.2,1.7,
     0.6,0.1,8.9,1.9,5.5,0.5,3.1,
     3.1,8.9,8.0,12.7,4.1,0.3,2.6,
     1.5,8.0,4.6,0.7,0.7,6.6,4.9,
     0.1,4.4,3.2,11.0,7.9,0.0,1.3,
     2.4,0.1,2.8,4.9,3.5,6.1,0.1]
n_bins = 5     #no of bins 
#patches is the specifics of histogram diagram measurements
bin_heights, bins, patches = plt.hist(x,bins=n_bins,facecolor='orange')
plt.show()

# %%
bin_heights
# Out:
# array([20., 11.,  6.,  2.,  3.])

# %%
bins
# Out:
# array([ 0.  ,  2.74,  5.48,  8.22, 10.96, 13.7 ])

# %%
print(patches[0])
# Out:
# Rectangle(xy=(2.22045e-16, 0), width=2.74, height=20, angle=0)

# %%
#to create unequally sized bins

n_bins = [3,4,6,7,9,12,15]     #bin values
bin_heights, bins, patches = plt.hist(x, n_bins, facecolor='orange')
plt.show()

# %%
#cumulative histogram -> sets the bin height as, plotted_bin(n) = actual_bin(n) + plotted_bin(n-1) for all bins
plt.hist(x, cumulative=True, facecolor='orange')
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt

x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5
#n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.hist(x, num_bins, facecolor='blue', alpha=0.5)#alpha is the transparency
plt.show()

# %%
#!/usr/bin/env python

import numpy as np
#import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from scipy.stats import norm
# example data
mu = 100 # mean of distribution
sigma = 15 # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)
                            #used to generate standard normal variate

num_bins = 20
# the histogram of the data
n, bins, patches = plt.hist(x, num_bins, density=1, alpha=0.7)

# add a 'best fit' line
y = norm.pdf(bins, mu, sigma)
plt.plot(bins, y, 'r--')
plt.xlabel('Smarts');plt.ylabel('Probability')
plt.title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %%
n
# Out:
# array([3.47618309e-05, 1.73809154e-05, 1.39047324e-04, 3.47618309e-04,
#        1.11237859e-03, 2.46808999e-03, 5.17951280e-03, 9.52474166e-03,
#        1.64075842e-02, 2.17956680e-02, 2.60713732e-02, 2.65058961e-02,
#        2.32730458e-02, 1.70159162e-02, 1.23752118e-02, 6.46570055e-03,
#        3.11118386e-03, 1.28618774e-03, 4.69284717e-04, 2.08570985e-04])

# %%
import pandas as pd
#import numpy as np
df = pd.DataFrame(
    np.random.randint(1, 8, 5000),
    columns = ['one'])

# %%
df
# Out:
#       one
# 0       5
# 1       2
# 2       7
# 3       6
# 4       7
# ...   ...
# 4995    2
# 4996    6
# 4997    7
# 4998    4
# 4999    4
#
# [5000 rows x 1 columns]

# %%
#%matplotlib inline
ax = df.plot.hist(bins=10, alpha=0.5)

# %%
df['two'] = df['one'] + np.random.randint(1, 8, 5000)
ax = df.plot.hist(bins=10, alpha=0.5)
